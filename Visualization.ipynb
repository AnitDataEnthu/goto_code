# %%
import pandas as pd;
import os;
os.getcwd()
# Out:
# '/Users/agupta/Documents/JOBS/TArget/Case study practise/python-reference-master'

# %%
data=pd.read_csv("Pokemon.csv",encoding = "ISO-8859-1", engine='python',index_col=0)

# %%
data
# Out:
#            Name   Type 1  Type 2  Total   HP  Attack  Defense  Sp. Atk  \
# #
# 1     Bulbasaur    Grass  Poison    318   45      49       49       65
# 2       Ivysaur    Grass  Poison    405   60      62       63       80
# 3      Venusaur    Grass  Poison    525   80      82       83      100
# 4    Charmander     Fire     NaN    309   39      52       43       60
# 5    Charmeleon     Fire     NaN    405   58      64       58       80
# ..          ...      ...     ...    ...  ...     ...      ...      ...
# 147     Dratini   Dragon     NaN    300   41      64       45       50
# 148   Dragonair   Dragon     NaN    420   61      84       65       70
# 149   Dragonite   Dragon  Flying    600   91     134       95      100
# 150      Mewtwo  Psychic     NaN    680  106     110       90      154
# 151         Mew  Psychic     NaN    600  100     100      100      100
#
#      Sp. Def  Speed  Stage  Legendary
# #
# 1         65     45      1      False
# ...

# %%
data_plot=data.groupby(by=["Type 1"]).count()['Name']
df=data_plot.reset_index()
df
# Out:
#       Type 1  Name
# 0        Bug    12
# 1     Dragon     3
# 2   Electric     9
# 3      Fairy     2
# 4   Fighting     7
# 5       Fire    12
# 6      Ghost     3
# 7      Grass    12
# 8     Ground     8
# 9        Ice     2
# 10    Normal    22
# 11    Poison    14
# 12   Psychic     8
# 13      Rock     9
# 14     Water    28

# %%
data.columns
# Out:
# Index(['Name', 'Type 1', 'Type 2', 'Total', 'HP', 'Attack', 'Defense',
#        'Sp. Atk', 'Sp. Def', 'Speed', 'Stage', 'Legendary'],
#       dtype='object')

# %%
from bokeh.plotting import figure
from bokeh.io import output_notebook,show,curdoc
from bokeh.themes import built_in_themes
from bokeh.models import ColumnDataSource, HoverTool
curdoc().theme = 'dark_minimal'
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1001">Loading BokehJS ...</span>
#     </div>

# %%
p = figure(
            plot_width=600, 
            plot_height=400,
            title="log axis example",
            x_axis_label='x',
            y_axis_label='y',
            y_axis_type="auto",#linear, log, datetime
            y_range=None,#[0,1000] ,
            tools="pan,box_zoom,reset,save",
   
)

#xticks
p.xaxis.major_label_orientation = 45
p.xaxis.major_label_text_font_size="12px"
#xlabels 
p.xaxis.axis_label_text_font_size="12px"




#hover tool properties
p.add_tools(HoverTool(tooltips=[
        ("X value", "$x"),
        ("Y value", "$y"),
]))
x = data['Sp. Atk']
y =  data['Sp. Atk']

#plot line graphs
p.circle(x,y,line_width=2,legend_label="y=10^x")#line,square,parameter-line_dash(4,4)
p.line(x,y,line_width=2,legend_label="y=10")

#legends -- placed after the graph always 
p.legend.location='top_left'
p.legend.title='legend_title'
p.legend.title_text_font='Arial'
p.legend.title_text_font_size='20pt'
p.legend.title_text_color="white"
p.legend.title_text_font_style="italic"
p.legend.click_policy="hide"#mute




show(p)
# Out:
#   <div class="bk-root" id="39238aab-02cc-435a-ba82-a279fe22fa0a" data-root-id="1002"></div>

# %% [markdown]
# ## BAR PLOT

# %%
# from bokeh.plotting import figure
# fruits = ['Apples', 'Pears', 'Nectarines', 'Plums', 'Grapes', 'Strawberries']
# counts = [5, 3, 4, 2, 4, 6]
# p = figure(
#             plot_width=600, 
#             plot_height=400,
#             title="log axis example",
#             x_axis_label='x',
#             y_axis_label='y',
#             y_axis_type="auto",#linear, log, datetim
#             y_range=None,#[0,1000] ,
#             tools="",#"pan,box_zoom,reset,save", 
   
# )

# graph = figure(title = "Bokeh Horizontal Bar Graph") 
  
# # y-coordinates to be plotted 
# y = ['Anit', 2, 3, 4, 5] 
  
# # x-coordinates of the right edges 
# right = [1, 2, 3, 4, 5] 
  
# # height / thickness of the bars  
# height = 0.5
  
# # plotting the graph 
# graph.hbar(y, 
#            right = right, 
#            height = height) 
  
# # displaying the model 
# show(graph)

# %%
list(df['Type 1'])
# Out:
# ['Bug',
#  'Dragon',
#  'Electric',
#  'Fairy',
#  'Fighting',
#  'Fire',
#  'Ghost',
#  'Grass',
#  'Ground',
#  'Ice',
#  'Normal',
#  'Poison',
#  'Psychic',
#  'Rock',
#  'Water']

# %%
from bokeh.io import output_file, show
from bokeh.models import ColumnDataSource
from bokeh.palettes import Spectral6
from bokeh.plotting import figure
from bokeh.transform import factor_cmap


y = ['Apples', 'Pears', 'Nectarines', 'Plums', 'Grapes', 'Strawberries']
right = [5, 3, 4, 2, 4, 6]

source = ColumnDataSource(data=dict(y=y, right=right))

p = figure(x_range=fruits, plot_height=250, toolbar_location=None, title="Fruit Counts")
p.hbar(y="y", right="right", width=0.9, source=source, legend_field="fruits",
       line_color='white', fill_color=factor_cmap('fruits', palette=Spectral6, factors=fruits))

p.xgrid.grid_line_color = None
p.y_range.start = 0
p.y_range.end = 9
p.legend.orientation = "horizontal"
p.legend.location = "top_center"

show(p)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-30-1458ef985941> in <module>
#      11 source = ColumnDataSource(data=dict(y=y, right=right))
#      12
# ---> 13 p = figure(x_range=fruits, plot_height=250, toolbar_location=None, title="Fruit Counts")
#      14 p.hbar(y="y", right="right", width=0.9, source=source, legend_field="fruits",
#      15        line_color='white', fill_color=factor_cmap('fruits', palette=Spectral6, factors=fruits))
#
# NameError: name 'fruits' is not defined

# %% [markdown]
# ## Line Plots

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style("darkgrid")

# %%
plt.figure(figsize=(8,9))
# plot



plt.xlabel('Sp. Atk',fontsize='x-large',fontstyle='italic')
plt.xlim(left=1,right=200)
plt.xscale('linear')#linear,symlog,logit

plt.title('title of the plot',fontdict={'fontsize':'xx-large',
                                        'color': 'Red',
                                        'horizontalalignment':'center',
                                        'verticalalignment':'baseline'})

ax=sns.lineplot(data=data,x="Sp. Atk",y="Sp. Atk", size="Type 1",hue="Type 2",sizes=(.25, 2.5))
ax.lines[0].set_linestyle("dotted")
plt.show()

# %% [markdown]
# ## Barplot

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style("darkgrid")

# %%
from numpy import median
plt.style.use('fivethirtyeight')
plt.figure(figsize=(12,7))
plt.title('title of the plot',fontdict={'fontsize':'xx-large',
                                        'color': 'Red',
                                        'horizontalalignment':'center',
                                        'verticalalignment':'baseline'})
plt.xticks(fontsize='large',fontstyle='italic',rotation=45)
plt.xlabel('Type 1 ',fontsize='xx-large',fontstyle='normal')
#plt.xlim(left=1,right=200)
#plt.xscale('linear')#linear,symlog,logit


sns.barplot(x="Type 1",y="Name",data=df ,#order=['Bug','Dragon'],
            palette="Blues_d")

# %%
from numpy import median
plt.style.use('fivethirtyeight')
plt.figure(figsize=(12,7))
plt.title('title of the plot',fontdict={'fontsize':'xx-large',
                                        'color': 'Red',
                                        'horizontalalignment':'center',
                                        'verticalalignment':'baseline'})
plt.xticks(fontsize='large',fontstyle='italic',rotation=45)
plt.xlabel('Type 1 ',fontsize='xx-large',fontstyle='normal')
#plt.xlim(left=1,right=200)
#plt.xscale('linear')#linear,symlog,logit

sns.barplot(x="Name",y="Type 1",data=df ,#order=['Bug','Dragon'],
            palette="Blues_d",orient="h")

# %% [markdown]
# # BoxPlots

# %%
plt.style.use('fivethirtyeight')
cols=data.columns
for col in cols:
    if data[col].dtype==int:
        #ax = sns.boxenplot(data[col], orient='h')
        ax = sns.boxplot(data[col], orient='h')
        ax = sns.swarmplot(data[col], color=".25")
        plt.show()
# Out:
# /Users/agupta/opt/anaconda3/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning:
#
# Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#
# /Users/agupta/opt/anaconda3/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning:
#
# Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
# /Users/agupta/opt/anaconda3/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning:
#
# Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#
# ...

# %% [markdown]
# ## violin plots

# %%
plt.style.use('fivethirtyeight')
sns.violinplot(data['Stage'],inner="quartile",palette="Set2")
# Out:
# /Users/agupta/opt/anaconda3/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning:
#
# Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.

# %% [markdown]
# # histograms

# %%
plt.style.use('fivethirtyeight')
sns.countplot(data=data,x="Stage")

# %%
# Data
x=data["Type 1"][0:10]
y=[ data["HP"][0:10], data["Speed"][0:10],data["Total"][0:10]]
plt.style.use('fivethirtyeight')
# Plot
plt.stackplot(x,y, labels=['Total','HP','Speed'])
plt.legend(loc='upper right',facecolor='Black',)
plt.show()

# %% [markdown]
# # Tree Map

# %%
#!pip install plotly
import plotly.express as px 

fig = px.treemap(df, path=['Type 1'], 
                 values='Name') 
  
fig.show()
# Out:
# <div>
#
#
#             <div id="bdafe41a-9f78-4ddd-a3c2-5fa0b1800cb6" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("bdafe41a-9f78-4ddd-a3c2-5fa0b1800cb6")) {
#                     Plotly.newPlot(
#                         'bdafe41a-9f78-4ddd-a3c2-5fa0b1800cb6',
# ...

# %% [markdown]
# # PieChart

# %%
# This dataframe has 244 lines, but 4 distinct values for `day`
fig = px.pie(df, values='Name', names='Type 1',color_discrete_sequence=px.colors.sequential.RdBu,hole=.2)
fig.show()
# Out:
# <div>
#
#
#             <div id="e342482a-c8c3-409e-a80a-d76bd58ee160" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("e342482a-c8c3-409e-a80a-d76bd58ee160")) {
#                     Plotly.newPlot(
#                         'e342482a-c8c3-409e-a80a-d76bd58ee160',
#                         [{"domain": {"x": [0.0, 1.0], "y": [0.0, 1.0]}, "hole": 0.2, "hovertemplate": "Type 1=%{label}<br>Name=%{value}<extra></extra>", "labels": ["Bug", "Dragon", "Electric", "Fairy", "Fighting", "Fire", "Ghost", "Grass", "Ground", "Ice", "Normal", "Poison", "Psychic", "Rock", "Water"], "legendgroup": "", "name": "", "showlegend": true, "type": "pie", "values": [12, 3, 9, 2, 7, 12, 3, 12, 8, 2, 22, 14, 8, 9, 28]}],
# ...

# %% [markdown]
# # Geo Plots

# %%
import plotly.express as px
df = px.data.gapminder().query("year == 2007")
fig = px.scatter_geo(df, locations="iso_alpha",
                     color="continent", # which column to use to set the color of markers
                     hover_name="country", # column added to hover information
                     size="pop", # size of markers
                     projection="natural earth")
fig.show()
# Out:
# <div>
#
#
#             <div id="70d2a178-34e6-44c2-b439-b8eb218263d5" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("70d2a178-34e6-44c2-b439-b8eb218263d5")) {
#                     Plotly.newPlot(
#                         '70d2a178-34e6-44c2-b439-b8eb218263d5',
# ...

# %%
import pandas as pd
import plotly.graph_objects as go
df = pd.read_csv('https://raw.githubusercontent.com/plotly/datasets/master/2011_february_us_airport_traffic.csv')
df['text'] = df['airport'] + '' + df['city'] + ', ' + df['state'] + '' + 'Arrivals: ' + df['cnt'].astype(str)

fig = go.Figure(data=go.Scattergeo(
        lon = df['long'],
        lat = df['lat'],
        text = df['text'],
        mode = 'markers',
        marker_color = df['cnt'],
        ))

fig.update_layout(
        title = 'Most trafficked US airports<br>(Hover for airport names)',
        geo_scope='usa',
    )
fig.show()
# Out:
# <div>
#
#
#             <div id="dc4e576e-3422-4c2b-a860-fa53c3278062" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("dc4e576e-3422-4c2b-a860-fa53c3278062")) {
#                     Plotly.newPlot(
#                         'dc4e576e-3422-4c2b-a860-fa53c3278062',
# ...

# %% [markdown]
# # Distribution plots

# %%
#!pip install seaborn==0.11.0
import seaborn as sns
sns.displot(data=data, x="Total",y="Speed")

# %%
sns.displot(data=data, x="Total",kde=True,rug=True,hue="Stage")

# %% [markdown]
# # scatter Plots

# %%
sns.scatterplot(data=data, x="Total", y="Speed", hue="Stage",sizes=(200, 400), legend="full")

# %%
sns.pairplot(data, hue="Stage")
# Out:
# /Users/agupta/opt/anaconda3/lib/python3.7/site-packages/seaborn/distributions.py:305: UserWarning:
#
# Dataset has 0 variance; skipping density estimate.
#
# /Users/agupta/opt/anaconda3/lib/python3.7/site-packages/seaborn/distributions.py:305: UserWarning:
#
# Dataset has 0 variance; skipping density estimate.

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(12, 10))
corr=data.corr()
sns.heatmap(corr[(corr >= 0.5) | (corr <= -0.4)], 
            cmap='viridis', vmax=1.0, vmin=-1.0, linewidths=0.1,
            annot=True, annot_kws={"size": 8}, square=True);
